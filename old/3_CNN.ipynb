# %% [markdown]
# # Construction modèle

# %%
from cnn_model import build_model
model, base_model = build_model(img_shape)
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetv2-m (Function  (None, 8, 8, 1280)        53150388
#  al)
#
#  flatten_2 (Flatten)         (None, 81920)             0
#
#  dropout_8 (Dropout)         (None, 81920)             0
#
#  dense_10 (Dense)            (None, 2048)              167774208
#
#  dropout_9 (Dropout)         (None, 2048)              0
#
#  dense_11 (Dense)            (None, 1024)              2098176
#
#  dropout_10 (Dropout)        (None, 1024)              0
#
#  dense_12 (Dense)            (None, 512)               524800
#
#  dropout_11 (Dropout)        (None, 512)               0
#
#  dense_13 (Dense)            (None, 256)               131328
#
#  dense_14 (Dense)            (None, 10)                2570
#
# =================================================================
# Total params: 223681470 (853.28 MB)
# Trainable params: 170531082 (650.52 MB)
# Non-trainable params: 53150388 (202.75 MB)
# _________________________________________________________________
#
#
# \ Architecture modèle: None
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetv2-m (Function  (None, 8, 8, 1280)        53150388
#  al)
#
#  flatten_2 (Flatten)         (None, 81920)             0
#
#  dropout_8 (Dropout)         (None, 81920)             0
#
#  dense_10 (Dense)            (None, 2048)              167774208
#
#  dropout_9 (Dropout)         (None, 2048)              0
#
#  dense_11 (Dense)            (None, 1024)              2098176
#
#  dropout_10 (Dropout)        (None, 1024)              0
#
#  dense_12 (Dense)            (None, 512)               524800
#
#  dropout_11 (Dropout)        (None, 512)               0
#
#  dense_13 (Dense)            (None, 256)               131328
#
#  dense_14 (Dense)            (None, 10)                2570
#
# =================================================================
# Total params: 223681470 (853.28 MB)
# Trainable params: 170531082 (650.52 MB)
# Non-trainable params: 53150388 (202.75 MB)
# _________________________________________________________________

# %% [markdown]
# # Entrainement du modèle

# %% [markdown]
# ### Callbacks

# %%
# earlystopping défini pour réduire le temps d'entrainement si l'accuracy n'évolue plus.
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(monitor = 'accuracy',
                               min_delta = 0.05,
                               patience = 8,
                               verbose = 1,
                               mode = 'auto',
                               restore_best_weights = True)



# Reduction du learning Rate
from tensorflow.keras.callbacks import ReduceLROnPlateau

reduceLR = ReduceLROnPlateau(monitor = 'val_loss',
                             min_delta = 0.01,
                             patience = 5,
                             factor = 0.1,
                             cooldown = 2,
                             mode = 'min',
                             verbose = 2)





# Enregistrement du modèle en cas d'amélioration lors de l'entrainement, ne conserve que la meilleure itération
from tensorflow.keras.callbacks import ModelCheckpoint

checkpoint = ModelCheckpoint(filepath='../model/checkpoint_model',
                             monitor='val_loss',
                             save_best_only=True,
                             save_weights_only=False,
                             mode = 'min',
                             save_freq='epoch',
                             verbose=1)




# Suivi du temps d'entrainement
from timeit import default_timer as timer
from tensorflow.keras.callbacks import Callback


class TimingCallback(Callback):
    def __init__(self):
        super().__init__()
        self.logs = []

    def on_epoch_begin(self, epoch, logs=None):
        self.starttime = timer()

    def on_epoch_end(self, epoch, logs=None):
        endtime = timer()
        elapsed_time = endtime - self.starttime
        self.logs.append(elapsed_time)
        print(f"Epoch {epoch + 1} took {elapsed_time:.2f} seconds")

time_callback = TimingCallback()

# %% [markdown]
# ### Methode .fit

# %%
from tensorflow.keras.optimizers import Adam
model.compile(Adam(learning_rate = learning_rate),
              loss = 'sparse_categorical_crossentropy',
              metrics = ['accuracy'])

# %%
history = model.fit(dataset_train,
                    validation_data = dataset_val,
                    epochs = epochs,
                    callbacks = [early_stopping, reduceLR, checkpoint, time_callback],
                    verbose=True)
# Out:
# Epoch 1/20
# 368/368 [==============================] - ETA: 0s - loss: 5.0806 - accuracy: 0.2007
# Epoch 1: val_loss did not improve from 3.02804
# Epoch 1 took 113.37 seconds
# 368/368 [==============================] - 113s 241ms/step - loss: 5.0806 - accuracy: 0.2007 - val_loss: 4.3066 - val_accuracy: 0.2850 - lr: 1.0000e-04
# Epoch 2/20
# 368/368 [==============================] - ETA: 0s - loss: 3.9391 - accuracy: 0.2933
# Epoch 2: val_loss did not improve from 3.02804
# Epoch 2 took 82.19 seconds
# 368/368 [==============================] - 82s 223ms/step - loss: 3.9391 - accuracy: 0.2933 - val_loss: 3.4033 - val_accuracy: 0.3778 - lr: 1.0000e-04
# Epoch 3/20
# 368/368 [==============================] - ETA: 0s - loss: 3.2083 - accuracy: 0.3509
# Epoch 3: val_loss improved from 3.02804 to 2.79560, saving model to ../model/checkpoint_model
# Epoch 3 took 173.53 seconds
# 368/368 [==============================] - 174s 472ms/step - loss: 3.2083 - accuracy: 0.3509 - val_loss: 2.7956 - val_accuracy: 0.4286 - lr: 1.0000e-04
# Epoch 4/20
# 368/368 [==============================] - ETA: 0s - loss: 2.7029 - accuracy: 0.3965
# Epoch 4: val_loss improved from 2.79560 to 2.38048, saving model to ../model/checkpoint_model
# Epoch 4 took 174.49 seconds
# 368/368 [==============================] - 174s 475ms/step - loss: 2.7029 - accuracy: 0.3965 - val_loss: 2.3805 - val_accuracy: 0.4646 - lr: 1.0000e-04
# Epoch 5/20
# 368/368 [==============================] - ETA: 0s - loss: 2.3544 - accuracy: 0.4278
# Epoch 5: val_loss improved from 2.38048 to 2.09204, saving model to ../model/checkpoint_model
# Epoch 5 took 178.34 seconds
# 368/368 [==============================] - 178s 485ms/step - loss: 2.3544 - accuracy: 0.4278 - val_loss: 2.0920 - val_accuracy: 0.4988 - lr: 1.0000e-04
# Epoch 6/20
# 368/368 [==============================] - ETA: 0s - loss: 2.1189 - accuracy: 0.4546
# Epoch 6: val_loss improved from 2.09204 to 1.89729, saving model to ../model/checkpoint_model
# Epoch 6 took 172.37 seconds
# 368/368 [==============================] - 172s 469ms/step - loss: 2.1189 - accuracy: 0.4546 - val_loss: 1.8973 - val_accuracy: 0.5224 - lr: 1.0000e-04
# Epoch 7/20
# 368/368 [==============================] - ETA: 0s - loss: 1.9382 - accuracy: 0.4752
# Epoch 7: val_loss improved from 1.89729 to 1.75385, saving model to ../model/checkpoint_model
# Epoch 7 took 174.86 seconds
# 368/368 [==============================] - 175s 476ms/step - loss: 1.9382 - accuracy: 0.4752 - val_loss: 1.7538 - val_accuracy: 0.5264 - lr: 1.0000e-04
# Epoch 8/20
# 368/368 [==============================] - ETA: 0s - loss: 1.7997 - accuracy: 0.4960
# Epoch 8: val_loss improved from 1.75385 to 1.63591, saving model to ../model/checkpoint_model
# Epoch 8 took 176.97 seconds
# 368/368 [==============================] - 177s 482ms/step - loss: 1.7997 - accuracy: 0.4960 - val_loss: 1.6359 - val_accuracy: 0.5454 - lr: 1.0000e-04
# Epoch 9/20
# 368/368 [==============================] - ETA: 0s - loss: 1.6967 - accuracy: 0.5095
# Epoch 9: val_loss improved from 1.63591 to 1.54657, saving model to ../model/checkpoint_model
# Epoch 9 took 176.51 seconds
# 368/368 [==============================] - 177s 480ms/step - loss: 1.6967 - accuracy: 0.5095 - val_loss: 1.5466 - val_accuracy: 0.5570 - lr: 1.0000e-04
# Epoch 10/20
# 368/368 [==============================] - ETA: 0s - loss: 1.6104 - accuracy: 0.5220
# Epoch 10: val_loss improved from 1.54657 to 1.47787, saving model to ../model/checkpoint_model
# Epoch 10 took 174.20 seconds
# 368/368 [==============================] - 174s 474ms/step - loss: 1.6104 - accuracy: 0.5220 - val_loss: 1.4779 - val_accuracy: 0.5646 - lr: 1.0000e-04
# Epoch 11/20
# 368/368 [==============================] - ETA: 0s - loss: 1.5437 - accuracy: 0.5318
# Epoch 11: val_loss improved from 1.47787 to 1.40844, saving model to ../model/checkpoint_model
# Epoch 11 took 176.02 seconds
# 368/368 [==============================] - 176s 479ms/step - loss: 1.5437 - accuracy: 0.5318 - val_loss: 1.4084 - val_accuracy: 0.5723 - lr: 1.0000e-04
# Epoch 12/20
# 368/368 [==============================] - ETA: 0s - loss: 1.4890 - accuracy: 0.5428
# Epoch 12: val_loss improved from 1.40844 to 1.36512, saving model to ../model/checkpoint_model
# Epoch 12 took 174.75 seconds
# 368/368 [==============================] - 175s 476ms/step - loss: 1.4890 - accuracy: 0.5428 - val_loss: 1.3651 - val_accuracy: 0.5875 - lr: 1.0000e-04
# Epoch 13/20
# 368/368 [==============================] - ETA: 0s - loss: 1.4306 - accuracy: 0.5535
# Epoch 13: val_loss improved from 1.36512 to 1.34192, saving model to ../model/checkpoint_model
# Epoch 13 took 174.22 seconds
# 368/368 [==============================] - 174s 474ms/step - loss: 1.4306 - accuracy: 0.5535 - val_loss: 1.3419 - val_accuracy: 0.5840 - lr: 1.0000e-04
# Epoch 14/20
# 368/368 [==============================] - ETA: 0s - loss: 1.3888 - accuracy: 0.5585
# Epoch 14: val_loss improved from 1.34192 to 1.29304, saving model to ../model/checkpoint_model
# Epoch 14 took 176.80 seconds
# 368/368 [==============================] - 177s 481ms/step - loss: 1.3888 - accuracy: 0.5585 - val_loss: 1.2930 - val_accuracy: 0.6005 - lr: 1.0000e-04
# Epoch 15/20
# 368/368 [==============================] - ETA: 0s - loss: 1.3507 - accuracy: 0.5699
# Epoch 15: val_loss did not improve from 1.29304
# Epoch 15 took 81.10 seconds
# 368/368 [==============================] - 81s 220ms/step - loss: 1.3507 - accuracy: 0.5699 - val_loss: 1.3090 - val_accuracy: 0.5826 - lr: 1.0000e-04
# Epoch 16/20
# 368/368 [==============================] - ETA: 0s - loss: 1.3058 - accuracy: 0.5837
# Epoch 16: val_loss improved from 1.29304 to 1.22773, saving model to ../model/checkpoint_model
# Epoch 16 took 174.98 seconds
# 368/368 [==============================] - 175s 476ms/step - loss: 1.3058 - accuracy: 0.5837 - val_loss: 1.2277 - val_accuracy: 0.6179 - lr: 1.0000e-04
# Epoch 17/20
# 368/368 [==============================] - ETA: 0s - loss: 1.2764 - accuracy: 0.5899
# Epoch 17: val_loss improved from 1.22773 to 1.21832, saving model to ../model/checkpoint_model
# Epoch 17 took 177.27 seconds
# 368/368 [==============================] - 177s 482ms/step - loss: 1.2764 - accuracy: 0.5899 - val_loss: 1.2183 - val_accuracy: 0.6177 - lr: 1.0000e-04
# Epoch 18/20
# 368/368 [==============================] - ETA: 0s - loss: 1.2451 - accuracy: 0.5961
# Epoch 18: val_loss improved from 1.21832 to 1.18818, saving model to ../model/checkpoint_model
# Epoch 18 took 179.33 seconds
# 368/368 [==============================] - 179s 488ms/step - loss: 1.2451 - accuracy: 0.5961 - val_loss: 1.1882 - val_accuracy: 0.6189 - lr: 1.0000e-04
# Epoch 19/20
# 368/368 [==============================] - ETA: 0s - loss: 1.2219 - accuracy: 0.6002
# Epoch 19: val_loss did not improve from 1.18818
# Epoch 19 took 81.33 seconds
# 368/368 [==============================] - 81s 221ms/step - loss: 1.2219 - accuracy: 0.6002 - val_loss: 1.2030 - val_accuracy: 0.6123 - lr: 1.0000e-04
# Epoch 20/20
# 368/368 [==============================] - ETA: 0s - loss: 1.1928 - accuracy: 0.6097
# Epoch 20: val_loss improved from 1.18818 to 1.16285, saving model to ../model/checkpoint_model
# Epoch 20 took 181.64 seconds
# 368/368 [==============================] - 182s 494ms/step - loss: 1.1928 - accuracy: 0.6097 - val_loss: 1.1629 - val_accuracy: 0.6337 - lr: 1.0000e-04

# %% [markdown]
# ### Fine tuning

# %%
for layer in base_model.layers:
    layer.trainable = True

model_fine_tuned = model
model_fine_tuned_name = model_name + '_fine_tuned'


model_fine_tuned.compile(Adam(learning_rate = learning_rate),
                         loss = 'sparse_categorical_crossentropy',
                         metrics = ['accuracy'])

# %%
fine_tune_epochs = 30
total_epochs =  epochs + fine_tune_epochs

history_fine_tuning = model_fine_tuned.fit(dataset_train,
                                           validation_data = dataset_val,
                                           epochs = total_epochs,
                                           initial_epoch=history.epoch[-1],
                                           callbacks = [early_stopping, reduceLR, checkpoint, time_callback],
                                           verbose=True)
# Out:
# Epoch 30/50
# 368/368 [==============================] - ETA: 0s - loss: 1.4641 - accuracy: 0.5067
# Epoch 30: val_loss did not improve from 1.16285
# Epoch 30 took 97.92 seconds
# 368/368 [==============================] - 98s 266ms/step - loss: 1.4641 - accuracy: 0.5067 - val_loss: 1.4287 - val_accuracy: 0.5209 - lr: 1.0000e-04
# Epoch 31/50
# 368/368 [==============================] - ETA: 0s - loss: 1.4429 - accuracy: 0.5099
# Epoch 31: val_loss did not improve from 1.16285
# Epoch 31 took 95.63 seconds
# 368/368 [==============================] - 96s 260ms/step - loss: 1.4429 - accuracy: 0.5099 - val_loss: 1.4071 - val_accuracy: 0.5250 - lr: 1.0000e-04
# Epoch 32/50
# 368/368 [==============================] - ETA: 0s - loss: 1.4197 - accuracy: 0.5194
# Epoch 32: val_loss did not improve from 1.16285
# Epoch 32 took 95.56 seconds
# 368/368 [==============================] - 96s 260ms/step - loss: 1.4197 - accuracy: 0.5194 - val_loss: 1.4003 - val_accuracy: 0.5345 - lr: 1.0000e-04
# Epoch 33/50
# 368/368 [==============================] - ETA: 0s - loss: 1.3931 - accuracy: 0.5313
# Epoch 33: val_loss did not improve from 1.16285
# Epoch 33 took 95.47 seconds
# 368/368 [==============================] - 95s 259ms/step - loss: 1.3931 - accuracy: 0.5313 - val_loss: 1.3916 - val_accuracy: 0.5355 - lr: 1.0000e-04
# Epoch 34/50
# 368/368 [==============================] - ETA: 0s - loss: 1.3680 - accuracy: 0.5394
# Epoch 34: val_loss did not improve from 1.16285
# Epoch 34 took 95.64 seconds
# 368/368 [==============================] - 96s 260ms/step - loss: 1.3680 - accuracy: 0.5394 - val_loss: 1.3817 - val_accuracy: 0.5392 - lr: 1.0000e-04
# Epoch 35/50
# 368/368 [==============================] - ETA: 0s - loss: 1.3427 - accuracy: 0.5444
# Epoch 35: val_loss did not improve from 1.16285
# Epoch 35 took 95.55 seconds
# 368/368 [==============================] - 96s 260ms/step - loss: 1.3427 - accuracy: 0.5444 - val_loss: 1.3577 - val_accuracy: 0.5439 - lr: 1.0000e-04
# Epoch 36/50
# 368/368 [==============================] - ETA: 0s - loss: 1.3275 - accuracy: 0.5531
# Epoch 36: val_loss did not improve from 1.16285
# Epoch 36 took 95.63 seconds
# 368/368 [==============================] - 96s 260ms/step - loss: 1.3275 - accuracy: 0.5531 - val_loss: 1.3521 - val_accuracy: 0.5513 - lr: 1.0000e-04
# Epoch 37/50
# 368/368 [==============================] - ETA: 0s - loss: 1.2944 - accuracy: 0.5654
# Epoch 37: val_loss did not improve from 1.16285
# Epoch 37 took 96.64 seconds
# 368/368 [==============================] - 97s 263ms/step - loss: 1.2944 - accuracy: 0.5654 - val_loss: 1.3551 - val_accuracy: 0.5553 - lr: 1.0000e-04
# Epoch 38/50
# 368/368 [==============================] - ETA: 0s - loss: 1.2757 - accuracy: 0.5709
# Epoch 38: val_loss did not improve from 1.16285
# Epoch 38 took 95.58 seconds
# 368/368 [==============================] - 96s 260ms/step - loss: 1.2757 - accuracy: 0.5709 - val_loss: 1.3234 - val_accuracy: 0.5601 - lr: 1.0000e-04
# Epoch 39/50
# 368/368 [==============================] - ETA: 0s - loss: 1.2469 - accuracy: 0.5802
# Epoch 39: val_loss did not improve from 1.16285
# Epoch 39 took 95.66 seconds
# 368/368 [==============================] - 96s 260ms/step - loss: 1.2469 - accuracy: 0.5802 - val_loss: 1.3245 - val_accuracy: 0.5580 - lr: 1.0000e-04
# Epoch 40/50
# 368/368 [==============================] - ETA: 0s - loss: 1.2477 - accuracy: 0.5831
# Epoch 40: val_loss did not improve from 1.16285
# Epoch 40 took 95.63 seconds
# 368/368 [==============================] - 96s 260ms/step - loss: 1.2477 - accuracy: 0.5831 - val_loss: 1.3117 - val_accuracy: 0.5694 - lr: 1.0000e-04
# Epoch 41/50
# 368/368 [==============================] - ETA: 0s - loss: 1.2225 - accuracy: 0.5896
# Epoch 41: val_loss did not improve from 1.16285
# Epoch 41 took 95.67 seconds
# 368/368 [==============================] - 96s 260ms/step - loss: 1.2225 - accuracy: 0.5896 - val_loss: 1.3072 - val_accuracy: 0.5663 - lr: 1.0000e-04
# Epoch 42/50
# 368/368 [==============================] - ETA: 0s - loss: 1.2017 - accuracy: 0.5955
# Epoch 42: val_loss did not improve from 1.16285
# Epoch 42 took 95.78 seconds
# 368/368 [==============================] - 96s 260ms/step - loss: 1.2017 - accuracy: 0.5955 - val_loss: 1.2911 - val_accuracy: 0.5704 - lr: 1.0000e-04
# Epoch 43/50
# 368/368 [==============================] - ETA: 0s - loss: 1.1980 - accuracy: 0.5998
# Epoch 43: val_loss did not improve from 1.16285
# Epoch 43 took 95.52 seconds
# 368/368 [==============================] - 96s 260ms/step - loss: 1.1980 - accuracy: 0.5998 - val_loss: 1.2909 - val_accuracy: 0.5761 - lr: 1.0000e-04
# Epoch 44/50
# 368/368 [==============================] - ETA: 0s - loss: 1.1688 - accuracy: 0.6119
# Epoch 44: val_loss did not improve from 1.16285
# Epoch 44 took 95.61 seconds
# 368/368 [==============================] - 96s 260ms/step - loss: 1.1688 - accuracy: 0.6119 - val_loss: 1.2817 - val_accuracy: 0.5755 - lr: 1.0000e-04
# Epoch 45/50
# 368/368 [==============================] - ETA: 0s - loss: 1.1477 - accuracy: 0.6139Restoring model weights from the end of the best epoch: 37.
#
# Epoch 45: val_loss did not improve from 1.16285
# Epoch 45 took 97.00 seconds
# 368/368 [==============================] - 97s 264ms/step - loss: 1.1477 - accuracy: 0.6139 - val_loss: 1.2673 - val_accuracy: 0.5855 - lr: 1.0000e-04
# Epoch 45: early stopping

# %% [markdown]
# # Evaluation

# %% [markdown]
# ### Model

# %%
import matplotlib.pyplot as plt

# Courbes d'évolution de l'accuracy et de la val_accuracy
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Courbes d'évolution de la loss et de la val_loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
test_results = model.evaluate(dataset_test)
print("Resultats de la prediction:", test_results)

y_pred = model.predict(dataset_test)
# Out:
# 32/32 [==============================] - 6s 175ms/step - loss: 1.1508 - accuracy: 0.6365
# Resultats de la prediction: [1.1507598161697388, 0.6364536881446838]
# 32/32 [==============================] - 11s 147ms/step

# %%
# Rapport de classification
y_test = []
for _, label in dataset_test:
    y_test.extend(label.numpy())
y_test = np.array(y_test)


y_pred_classes = np.argmax(y_pred, axis=1)

from sklearn.metrics import classification_report
report = classification_report(y_test, y_pred_classes)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.63      0.56      0.60       199
#            1       0.63      0.79      0.70       191
#            2       0.70      0.46      0.55       212
#            3       0.67      0.46      0.54       199
#            4       0.75      0.76      0.76       196
#            5       0.60      0.62      0.61       216
#            6       0.64      0.83      0.72       202
#            7       0.52      0.58      0.55       192
#            8       0.57      0.62      0.59       204
#            9       0.68      0.71      0.70       208
#
#     accuracy                           0.64      2019
#    macro avg       0.64      0.64      0.63      2019
# weighted avg       0.64      0.64      0.63      2019

# %%
# Matrice de confusion
import seaborn as sns
from sklearn.metrics import confusion_matrix

confusion_mtx = confusion_matrix(y_test, y_pred_classes)
# Créer une figure pour afficher la matrice de confusion
plt.figure(figsize=(8, 8))
sns.heatmap(confusion_mtx, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Prédictions')
plt.ylabel('Vraies étiquettes')
plt.title('Matrice de confusion')
plt.show()

# %% [markdown]
# ### Model_fine_tuned

# %%
import matplotlib.pyplot as plt

# Courbes d'évolution de l'accuracy et de la val_accuracy
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history_fine_tuning.history['accuracy'], label='Training Accuracy')
plt.plot(history_fine_tuning.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Evolution lors du fine tuning du modèle')

plt.legend()

# Courbes d'évolution de la loss et de la val_loss
plt.subplot(1, 2, 2)
plt.plot(history_fine_tuning.history['loss'], label='Training Loss')
plt.plot(history_fine_tuning.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Evolution lors du fine tuning du modèle')
plt.legend()
plt.show();

# %%
test_results = model_fine_tuned.evaluate(dataset_test)
print("Resultats de la prediction:", test_results)

y_pred = model_fine_tuned.predict(dataset_test)
# Out:
# 32/32 [==============================] - 5s 154ms/step - loss: 1.3326 - accuracy: 0.5453
# Resultats de la prediction: [1.332647681236267, 0.5453194379806519]
# 32/32 [==============================] - 5s 148ms/step

# %%
# Rapport de classification
y_test = []
for _, label in dataset_test:
    y_test.extend(label.numpy())
y_test = np.array(y_test)


y_pred_classes = np.argmax(y_pred, axis=1)

from sklearn.metrics import classification_report
report = classification_report(y_test, y_pred_classes)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.59      0.46      0.52       199
#            1       0.54      0.63      0.58       191
#            2       0.54      0.44      0.49       212
#            3       0.45      0.44      0.45       199
#            4       0.67      0.58      0.62       196
#            5       0.50      0.52      0.51       216
#            6       0.56      0.76      0.65       202
#            7       0.53      0.52      0.52       192
#            8       0.59      0.49      0.53       204
#            9       0.52      0.62      0.57       208
#
#     accuracy                           0.55      2019
#    macro avg       0.55      0.55      0.54      2019
# weighted avg       0.55      0.55      0.54      2019

# %%
# Matrice de confusion
import seaborn as sns
from sklearn.metrics import confusion_matrix

confusion_mtx = confusion_matrix(y_test, y_pred_classes)
# Créer une figure pour afficher la matrice de confusion
plt.figure(figsize=(8, 8))
sns.heatmap(confusion_mtx, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Prédictions')
plt.ylabel('Vraies étiquettes')
plt.title('Matrice de confusion')
plt.show()

# %% [markdown]
# # Sauvegarde du modèle

# %%
print(model_name)
print(model_fine_tuned_name)
# Out:
# /content/drive/MyDrive/SAS/model/V0_tri_full_undersample
# V0_tri_full_undersample_fine_tuned
# /content/drive/MyDrive/SAS/history/history_fine_tuning.pkl

# %%
if work_env == '2':
    model_name = '/content/drive/MyDrive/SAS/model/' + model_name
    model_fine_tuned_name = '/content/drive/MyDrive/SAS/model/' + model_fine_tuned_name
    #history_path = '/content/drive/MyDrive/SAS/history/history.pkl'
    history_fine_tuning_path = '/content/drive/MyDrive/SAS/history/history_fine_tuning.pkl'


else:
    model_name = '../model/' + model_name
    model_fine_tuned_name = '../model/' + model_fine_tuned_name
    history_path = '../history/history.pkl'
    history_fine_tuning_path = '../history/history_fine_tuning.pkl'


model.save(model_name, save_format='h5')


import pickle
with open(history_path, 'wb') as file:
    pickle.dump(history.history, file)

with open(history_fine_tuning_path, 'wb') as file:
    pickle.dump(history_fine_tuning.history, file)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
